# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob
import cv2
import tensorflow as tf
import tensorflow_hub as hub
import warnings
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
warnings.filterwarnings('ignore')

# %%
# print(f"{tf.test.is_gpu_available()}")
# tf.config.list_physical_devices('GPU')
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# # Data Preprocessing

# %%
train_path = r"/kaggle/input/nn23-sports-image-classification/Train"
test_path =r"/kaggle/input/nn23-sports-image-classification/Test"
# train_path = r"Train"
# test_path =r"Test"

# %%
train_imgs=os.listdir(train_path)
test_imgs=os.listdir(test_path)

# %%
code = {'Basketball' : 0 , 'Football' : 1 , 'Rowing' : 2 , 'Swimming' :3 ,"Tennis" : 4 , "Yoga" : 5}

def get_name(n):

    for x,y in code.items() :
        if y == n :
            return x

# %%
#get labels for training
train_labels = []

for cur_img in train_imgs:
    if "Basketball" in cur_img :
        label = (code["Basketball"])
    elif "Football" in cur_img :
        label = (code["Football"])
    elif "Rowing" in cur_img :
        label = (code["Rowing"])
    elif "Swimming" in cur_img :
        label = (code["Swimming"])
    elif "Tennis" in cur_img :
        label = (code["Tennis"])
    elif "Yoga" in cur_img :
        label = (code["Yoga"])

    train_labels.append(label)

# %%
#reading images 
def reading_resize(train_imgs,train_path,image_size):
    l=[]
    for g in train_imgs:   
        img_path=os.path.join(train_path,g)
        img=cv2.imread(img_path)   
        img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        res = cv2.resize(img, (image_size, image_size))
        l.append(res)
        
    return l

# %%
#reading training data
image_size=224
l_train=reading_resize(train_imgs,train_path,image_size)

# %%
train = np.array(l_train)
labels=np.array(train_labels)
print(train.shape)
# Out:
# (1681, 224, 224, 3)

# %%
plt.imshow(train[0])
print(get_name(labels[0]))
# Out:
# Yoga

# %%
pd.DataFrame(labels).value_counts()
# Out:
# 5    458
# 1    400
# 3    240
# 2    202
# 0    196
# 4    185
# dtype: int64

# %%
X_train, X_val, y_train, y_val = train_test_split(train , labels, test_size = 0.2,stratify=labels,shuffle=True)

X_train =X_train/255.0
X_val =X_val/255.0

# %%
# Train labels
y_train=tf.keras.utils.to_categorical(y_train)

# Test labels
y_val=tf.keras.utils.to_categorical(y_val)

# %%
y_train.shape
# Out:
# (1344, 6)

# %%
plt.imshow(X_train[0])
print(get_name(np.argmax(y_train[0])))
# Out:
# Yoga

# %% [markdown]
# # Model [mobilenet_v2 224x224]

# %%
def Convolution(Input, FC, kernel=(3, 3), stride=(1, 1)):   

    #==================================== target output 112 x 112 x 32 

    # padding: Int, or tuple of 2 ints, or tuple of 2 tuples of 2 ints.
    # If int: the same symmetric padding is applied to height and width.
    # If tuple of 2 ints: interpreted as two different symmetric padding values for height and width: (symmetric_height_pad, symmetric_width_pad).
    # If tuple of 2 tuples of 2 ints: interpreted as ((top_pad, bottom_pad), (left_pad, right_pad))
    x = tf.keras.layers.ZeroPadding2D(padding=((0, 1), (0, 1)))(Input) 

    # padding = 'valid' where no padding applied or 'same' results in padding with zeros evenly to the left/right or up/down of the input
    x = tf.keras.layers.Conv2D(FC, kernel,padding='valid',use_bias=False,strides=stride)(x)
 
    # Batch-Normalization (BN) is an algorithmic method which makes the training of Deep Neural Networks (DNN) faster and more stable.
    # It consists of normalizing activation vectors from hidden layers using the first and the second statistical moments (mean and variance) of the current batch. 
    # steps:=
    # 1) The BN layer first determines the mean 𝜇 and the variance σ² of the activation values across the batch.
    # 2) Then normalizes the activation vector.
    # 3)  finally calculates the layer’s output by applying a linear transformation with 𝛾 and 𝛽, two trainable parameters.
    # Such step allows the model to choose the optimum distribution for each hidden layers, by adjusting those two parameters.
    # 𝛾 ==> allows to adjust the standard deviation.
    # 𝛽 ==> allows to adjust the bias, shifting the curve on the right or on the left side.  
    x = tf.keras.layers.BatchNormalization(axis=-1)(x)

    
    # With default values, it returns element-wise max(x, 0).
    # Otherwise, it follows: f(x) = max_value for x >= max_value, 
    #                        f(x) = x for threshold <= x < max_value, 
    #                        f(x) = negative_slope * (x - threshold) otherwise.
    # default: max_value=None, negative_slope=0.0, threshold=0.0
    x =tf.keras.layers.ReLU(6.0)(x) 

    return x

# %%
def DepthwiseConvolutionBlock(Input, FC_pointwise_conv, depth_multiplier=1, stride=(1, 1)):

    if stride == (1, 1):
        x = Input
    else:
        x = tf.keras.layers.ZeroPadding2D(((0, 1), (0, 1)))(Input)

    #========= first apply DEPTH WISE CONVOLUTION    
    # depth_multiplier: The number of depthwise convolution output channels for each input channel. 
    # The total number of depthwise convolution output channels will be equal to filters_in * depth_multiplier.
    x = tf.keras.layers.DepthwiseConv2D((3, 3),padding='same' if stride == (1, 1) else 'valid',depth_multiplier=depth_multiplier,strides=stride,use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization(axis=-1)(x)
    x = tf.keras.layers.ReLU(6.0)(x)

    #========= second apply POINT WISE CONVOLUTION
    x = tf.keras.layers.Conv2D(FC_pointwise_conv, (1, 1),padding='same',use_bias=False,strides=(1, 1))(x)
    x = tf.keras.layers.BatchNormalization(axis=-1)(x)
    x = tf.keras.layers.ReLU(6.0)(x)
    
    return x

# %%
input_shape=(224,224,3)
depth_multiplier=1                   
dropout=0.001               
classes=1000

# %%
InputLayer = tf.keras.layers.Input(shape=input_shape)                       
x = Convolution(InputLayer, 32, stride=(2, 2))                              
x = DepthwiseConvolutionBlock(x, 64, depth_multiplier)                       
x = DepthwiseConvolutionBlock(x, 128, depth_multiplier,stride=(2, 2))
x = DepthwiseConvolutionBlock(x, 128, depth_multiplier)
x = DepthwiseConvolutionBlock(x, 256, depth_multiplier, stride=(2, 2))
x = DepthwiseConvolutionBlock(x, 256, depth_multiplier)
x = DepthwiseConvolutionBlock(x, 512, depth_multiplier,stride=(2, 2))
x = DepthwiseConvolutionBlock(x, 512, depth_multiplier)
x = DepthwiseConvolutionBlock(x, 512, depth_multiplier)
x = DepthwiseConvolutionBlock(x, 512, depth_multiplier)
x = DepthwiseConvolutionBlock(x, 512, depth_multiplier)
x = DepthwiseConvolutionBlock(x, 512, depth_multiplier)
x = DepthwiseConvolutionBlock(x, 1024, depth_multiplier,stride=(2, 2))
x = DepthwiseConvolutionBlock(x, 1024, depth_multiplier)

# %%
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Reshape((1,1,1024))(x)
x = tf.keras.layers.Dropout(dropout)(x)
x = tf.keras.layers.Conv2D(classes, (1, 1),padding='same')(x)
x = tf.keras.layers.Reshape((classes,))(x)
x = tf.keras.layers.Activation('softmax')(x)

# %%
# Create model.
model = tf.keras.models.Model(InputLayer, x,name='Mobile_net_ver2_from_scratch')

# %%
# Load weights.
model.load_weights('/kaggle/input/weights-data/weights.h5')

# %%
len(model.layers)
# Out:
# 93

# %%
model.summary()
# Out:
# Model: "Mobile_net_ver2_from_scratch"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 225, 225, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 112, 112, 32)      864
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 112, 112, 32)      128
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 112, 112, 32)      0
# _________________________________________________________________
# depthwise_conv2d_4 (Depthwis (None, 112, 112, 32)      288
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 112, 112, 32)      128
# _________________________________________________________________
# re_lu_12 (ReLU)              (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 112, 112, 64)      2048
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# re_lu_13 (ReLU)              (None, 112, 112, 64)      0
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 113, 113, 64)      0
# _________________________________________________________________
# depthwise_conv2d_5 (Depthwis (None, 56, 56, 64)        576
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# re_lu_14 (ReLU)              (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 56, 56, 128)       8192
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_15 (ReLU)              (None, 56, 56, 128)       0
# _________________________________________________________________
# depthwise_conv2d_6 (Depthwis (None, 56, 56, 128)       1152
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 56, 56, 128)       0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 57, 57, 128)       0
# _________________________________________________________________
# depthwise_conv2d_7 (Depthwis (None, 28, 28, 128)       1152
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 28, 28, 256)       0
# _________________________________________________________________
# depthwise_conv2d_8 (Depthwis (None, 28, 28, 256)       2304
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# re_lu_20 (ReLU)              (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# re_lu_21 (ReLU)              (None, 28, 28, 256)       0
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 29, 29, 256)       0
# _________________________________________________________________
# depthwise_conv2d_9 (Depthwis (None, 14, 14, 256)       2304
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 14, 14, 256)       1024
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_10 (Depthwi (None, 14, 14, 512)       4608
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_25 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_11 (Depthwi (None, 14, 14, 512)       4608
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_26 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_27 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_12 (Depthwi (None, 14, 14, 512)       4608
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_28 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_29 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_13 (Depthwi (None, 14, 14, 512)       4608
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_30 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_31 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_14 (Depthwi (None, 14, 14, 512)       4608
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_32 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# re_lu_33 (ReLU)              (None, 14, 14, 512)       0
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 15, 15, 512)       0
# _________________________________________________________________
# depthwise_conv2d_15 (Depthwi (None, 7, 7, 512)         4608
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# re_lu_34 (ReLU)              (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 7, 7, 1024)        524288
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 7, 7, 1024)        4096
# _________________________________________________________________
# re_lu_35 (ReLU)              (None, 7, 7, 1024)        0
# _________________________________________________________________
# depthwise_conv2d_16 (Depthwi (None, 7, 7, 1024)        9216
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 7, 7, 1024)        4096
# _________________________________________________________________
# re_lu_36 (ReLU)              (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 7, 7, 1024)        4096
# _________________________________________________________________
# re_lu_37 (ReLU)              (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 1, 1, 1000)        1025000
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1000)              0
# _________________________________________________________________
# activation (Activation)      (None, 1000)              0
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
model.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

# %%
classes = 6
model2 = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer((224,224,3)),
    model,
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(classes)
])

# %%
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Mobile_net_ver2_from_scratch (None, 1000)              4253864
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 6006
# =================================================================
# Total params: 4,259,870
# Trainable params: 4,237,982
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
model2.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

# %% [markdown]
# # Training without Augmentation

# %%
Epochs=100
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model2.fit(X_train,y_train,
                    epochs=Epochs,
                    validation_data=(X_val,y_val),
                    batch_size=32,
                    verbose=1)#,callbacks=[early_stopping]
# Out:
# 2022-12-25 19:36:34.359870: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 809238528 exceeds 10% of free system memory.
#
# 2022-12-25 19:36:35.277122: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 809238528 exceeds 10% of free system memory.
#
# 2022-12-25 19:36:35.921381: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-12-25 19:36:38.640277: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 42/42 [==============================] - 11s 179ms/step - loss: 1.7758 - accuracy: 0.2664 - val_loss: 1.7487 - val_accuracy: 0.2700
#
# Epoch 2/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7404 - accuracy: 0.2939 - val_loss: 1.7123 - val_accuracy: 0.3769
#
# Epoch 3/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 1.7039 - accuracy: 0.3527 - val_loss: 1.6675 - val_accuracy: 0.4362
#
# Epoch 4/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 1.6477 - accuracy: 0.3966 - val_loss: 1.6041 - val_accuracy: 0.4748
#
# Epoch 5/100
#
# 42/42 [==============================] - 6s 155ms/step - loss: 1.5700 - accuracy: 0.5164 - val_loss: 1.5182 - val_accuracy: 0.4955
#
# Epoch 6/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 1.4817 - accuracy: 0.6057 - val_loss: 1.4124 - val_accuracy: 0.7062
#
# Epoch 7/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 1.3720 - accuracy: 0.6905 - val_loss: 1.2993 - val_accuracy: 0.7389
#
# Epoch 8/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 1.2606 - accuracy: 0.7411 - val_loss: 1.1987 - val_accuracy: 0.8279
#
# Epoch 9/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 1.1742 - accuracy: 0.7396 - val_loss: 1.1186 - val_accuracy: 0.8309
#
# Epoch 10/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 1.0925 - accuracy: 0.7485 - val_loss: 1.0477 - val_accuracy: 0.8398
#
# Epoch 11/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 1.0475 - accuracy: 0.7411 - val_loss: 0.9789 - val_accuracy: 0.8487
#
# Epoch 12/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.9890 - accuracy: 0.7820 - val_loss: 0.9247 - val_accuracy: 0.8843
#
# Epoch 13/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.9164 - accuracy: 0.8408 - val_loss: 0.8868 - val_accuracy: 0.8932
#
# Epoch 14/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.9020 - accuracy: 0.8371 - val_loss: 0.8318 - val_accuracy: 0.9436
#
# Epoch 15/100
#
# 42/42 [==============================] - 6s 155ms/step - loss: 0.8602 - accuracy: 0.8482 - val_loss: 0.7987 - val_accuracy: 0.9466
#
# Epoch 16/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.8686 - accuracy: 0.8229 - val_loss: 0.7640 - val_accuracy: 0.9585
#
# Epoch 17/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.8215 - accuracy: 0.8475 - val_loss: 0.7342 - val_accuracy: 0.9585
#
# Epoch 18/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.8046 - accuracy: 0.8430 - val_loss: 0.7150 - val_accuracy: 0.9614
#
# Epoch 19/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7543 - accuracy: 0.8631 - val_loss: 0.6931 - val_accuracy: 0.9644
#
# Epoch 20/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7468 - accuracy: 0.8571 - val_loss: 0.6771 - val_accuracy: 0.9644
#
# Epoch 21/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7702 - accuracy: 0.8408 - val_loss: 0.6631 - val_accuracy: 0.9674
#
# Epoch 22/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.7367 - accuracy: 0.8564 - val_loss: 0.6546 - val_accuracy: 0.9614
#
# Epoch 23/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7512 - accuracy: 0.8430 - val_loss: 0.6453 - val_accuracy: 0.9614
#
# Epoch 24/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7326 - accuracy: 0.8504 - val_loss: 0.6335 - val_accuracy: 0.9644
#
# Epoch 25/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7274 - accuracy: 0.8534 - val_loss: 0.6420 - val_accuracy: 0.9585
#
# Epoch 26/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7271 - accuracy: 0.8557 - val_loss: 0.6292 - val_accuracy: 0.9555
#
# Epoch 27/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7280 - accuracy: 0.8467 - val_loss: 0.6079 - val_accuracy: 0.9644
#
# Epoch 28/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7504 - accuracy: 0.8311 - val_loss: 0.5987 - val_accuracy: 0.9644
#
# Epoch 29/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7346 - accuracy: 0.8460 - val_loss: 0.6071 - val_accuracy: 0.9614
#
# Epoch 30/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7261 - accuracy: 0.8430 - val_loss: 0.6305 - val_accuracy: 0.9555
#
# Epoch 31/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7379 - accuracy: 0.8385 - val_loss: 0.6068 - val_accuracy: 0.9525
#
# Epoch 32/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7145 - accuracy: 0.8438 - val_loss: 0.5900 - val_accuracy: 0.9674
#
# Epoch 33/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7186 - accuracy: 0.8385 - val_loss: 0.5912 - val_accuracy: 0.9555
#
# Epoch 34/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7013 - accuracy: 0.8482 - val_loss: 0.5878 - val_accuracy: 0.9555
#
# Epoch 35/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7008 - accuracy: 0.8527 - val_loss: 0.5937 - val_accuracy: 0.9555
#
# Epoch 36/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.7290 - accuracy: 0.8378 - val_loss: 0.5969 - val_accuracy: 0.9555
#
# Epoch 37/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.7051 - accuracy: 0.8504 - val_loss: 0.5839 - val_accuracy: 0.9585
#
# Epoch 38/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7202 - accuracy: 0.8341 - val_loss: 0.5736 - val_accuracy: 0.9614
#
# Epoch 39/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7081 - accuracy: 0.8542 - val_loss: 0.6352 - val_accuracy: 0.9318
#
# Epoch 40/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7052 - accuracy: 0.8475 - val_loss: 0.5860 - val_accuracy: 0.9466
#
# Epoch 41/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7067 - accuracy: 0.8452 - val_loss: 0.5570 - val_accuracy: 0.9644
#
# Epoch 42/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7222 - accuracy: 0.8385 - val_loss: 0.5636 - val_accuracy: 0.9674
#
# Epoch 43/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7067 - accuracy: 0.8438 - val_loss: 0.5514 - val_accuracy: 0.9614
#
# Epoch 44/100
#
# 42/42 [==============================] - 7s 162ms/step - loss: 0.7127 - accuracy: 0.8408 - val_loss: 0.5495 - val_accuracy: 0.9644
#
# Epoch 45/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7055 - accuracy: 0.8475 - val_loss: 0.5488 - val_accuracy: 0.9674
#
# Epoch 46/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7033 - accuracy: 0.8460 - val_loss: 0.5466 - val_accuracy: 0.9674
#
# Epoch 47/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.6950 - accuracy: 0.8519 - val_loss: 0.5458 - val_accuracy: 0.9674
#
# Epoch 48/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6866 - accuracy: 0.8668 - val_loss: 0.5462 - val_accuracy: 0.9674
#
# Epoch 49/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7229 - accuracy: 0.8326 - val_loss: 0.5486 - val_accuracy: 0.9644
#
# Epoch 50/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6997 - accuracy: 0.8460 - val_loss: 0.5450 - val_accuracy: 0.9674
#
# Epoch 51/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7010 - accuracy: 0.8475 - val_loss: 0.5469 - val_accuracy: 0.9644
#
# Epoch 52/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7048 - accuracy: 0.8445 - val_loss: 0.5397 - val_accuracy: 0.9703
#
# Epoch 53/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6868 - accuracy: 0.8542 - val_loss: 0.5476 - val_accuracy: 0.9703
#
# Epoch 54/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7036 - accuracy: 0.8438 - val_loss: 0.5487 - val_accuracy: 0.9733
#
# Epoch 55/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6975 - accuracy: 0.8579 - val_loss: 0.5512 - val_accuracy: 0.9674
#
# Epoch 56/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6888 - accuracy: 0.8557 - val_loss: 0.5485 - val_accuracy: 0.9644
#
# Epoch 57/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7009 - accuracy: 0.8490 - val_loss: 0.5569 - val_accuracy: 0.9525
#
# Epoch 58/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7229 - accuracy: 0.8393 - val_loss: 0.5290 - val_accuracy: 0.9703
#
# Epoch 59/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6461 - accuracy: 0.8854 - val_loss: 0.5357 - val_accuracy: 0.9644
#
# Epoch 60/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6807 - accuracy: 0.8653 - val_loss: 0.5485 - val_accuracy: 0.9525
#
# Epoch 61/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7205 - accuracy: 0.8378 - val_loss: 0.5384 - val_accuracy: 0.9674
#
# Epoch 62/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6831 - accuracy: 0.8609 - val_loss: 0.5343 - val_accuracy: 0.9674
#
# Epoch 63/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.6868 - accuracy: 0.8542 - val_loss: 0.5314 - val_accuracy: 0.9703
#
# Epoch 64/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.6856 - accuracy: 0.8601 - val_loss: 0.5382 - val_accuracy: 0.9674
#
# Epoch 65/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6865 - accuracy: 0.8542 - val_loss: 0.5470 - val_accuracy: 0.9644
#
# Epoch 66/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.7071 - accuracy: 0.8408 - val_loss: 0.5432 - val_accuracy: 0.9644
#
# Epoch 67/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6682 - accuracy: 0.8668 - val_loss: 0.5410 - val_accuracy: 0.9644
#
# Epoch 68/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7179 - accuracy: 0.8274 - val_loss: 0.5393 - val_accuracy: 0.9644
#
# Epoch 69/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.6700 - accuracy: 0.8646 - val_loss: 0.5389 - val_accuracy: 0.9674
#
# Epoch 70/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7009 - accuracy: 0.8445 - val_loss: 0.5396 - val_accuracy: 0.9614
#
# Epoch 71/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6863 - accuracy: 0.8527 - val_loss: 0.5314 - val_accuracy: 0.9703
#
# Epoch 72/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.7093 - accuracy: 0.8400 - val_loss: 0.5275 - val_accuracy: 0.9703
#
# Epoch 73/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6814 - accuracy: 0.8690 - val_loss: 0.5263 - val_accuracy: 0.9733
#
# Epoch 74/100
#
# 42/42 [==============================] - 6s 155ms/step - loss: 0.7045 - accuracy: 0.8430 - val_loss: 0.5295 - val_accuracy: 0.9703
#
# Epoch 75/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.6775 - accuracy: 0.8586 - val_loss: 0.5286 - val_accuracy: 0.9733
#
# Epoch 76/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6986 - accuracy: 0.8467 - val_loss: 0.5301 - val_accuracy: 0.9733
#
# Epoch 77/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6990 - accuracy: 0.8512 - val_loss: 0.5360 - val_accuracy: 0.9644
#
# Epoch 78/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7188 - accuracy: 0.8408 - val_loss: 0.5223 - val_accuracy: 0.9763
#
# Epoch 79/100
#
# 42/42 [==============================] - 7s 155ms/step - loss: 0.6675 - accuracy: 0.8646 - val_loss: 0.5259 - val_accuracy: 0.9703
#
# Epoch 80/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7054 - accuracy: 0.8512 - val_loss: 0.5213 - val_accuracy: 0.9733
#
# Epoch 81/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7032 - accuracy: 0.8445 - val_loss: 0.5205 - val_accuracy: 0.9763
#
# Epoch 82/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6971 - accuracy: 0.8467 - val_loss: 0.5192 - val_accuracy: 0.9733
#
# Epoch 83/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6639 - accuracy: 0.8698 - val_loss: 0.5230 - val_accuracy: 0.9733
#
# Epoch 84/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.6743 - accuracy: 0.8638 - val_loss: 0.5212 - val_accuracy: 0.9733
#
# Epoch 85/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7138 - accuracy: 0.8430 - val_loss: 0.5189 - val_accuracy: 0.9763
#
# Epoch 86/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6940 - accuracy: 0.8475 - val_loss: 0.5188 - val_accuracy: 0.9792
#
# Epoch 87/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7013 - accuracy: 0.8504 - val_loss: 0.5254 - val_accuracy: 0.9733
#
# Epoch 88/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6873 - accuracy: 0.8564 - val_loss: 0.5227 - val_accuracy: 0.9763
#
# Epoch 89/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6614 - accuracy: 0.8728 - val_loss: 0.5206 - val_accuracy: 0.9763
#
# Epoch 90/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.6942 - accuracy: 0.8542 - val_loss: 0.5202 - val_accuracy: 0.9763
#
# Epoch 91/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.6967 - accuracy: 0.8445 - val_loss: 0.5182 - val_accuracy: 0.9763
#
# Epoch 92/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6969 - accuracy: 0.8519 - val_loss: 0.5302 - val_accuracy: 0.9644
#
# Epoch 93/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.7014 - accuracy: 0.8475 - val_loss: 0.5163 - val_accuracy: 0.9733
#
# Epoch 94/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.6628 - accuracy: 0.8668 - val_loss: 0.5089 - val_accuracy: 0.9822
#
# Epoch 95/100
#
# 42/42 [==============================] - 6s 152ms/step - loss: 0.6874 - accuracy: 0.8564 - val_loss: 0.5069 - val_accuracy: 0.9822
#
# Epoch 96/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7051 - accuracy: 0.8460 - val_loss: 0.5107 - val_accuracy: 0.9822
#
# Epoch 97/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.7250 - accuracy: 0.8333 - val_loss: 0.5122 - val_accuracy: 0.9792
#
# Epoch 98/100
#
# 42/42 [==============================] - 6s 153ms/step - loss: 0.6855 - accuracy: 0.8512 - val_loss: 0.5198 - val_accuracy: 0.9763
#
# Epoch 99/100
#
# 42/42 [==============================] - 6s 154ms/step - loss: 0.7086 - accuracy: 0.8445 - val_loss: 0.5312 - val_accuracy: 0.9733
#
# Epoch 100/100
#
# 42/42 [==============================] - 6s 151ms/step - loss: 0.6783 - accuracy: 0.8668 - val_loss: 0.5210 - val_accuracy: 0.9733

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(Epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model2.evaluate(X_train,y_train)
# Out:
# 2022-12-25 19:47:22.990266: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 809238528 exceeds 10% of free system memory.
#
# 2022-12-25 19:47:23.878159: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 809238528 exceeds 10% of free system memory.
# 42/42 [==============================] - 2s 27ms/step - loss: 0.4647 - accuracy: 0.9940
# [0.4646858870983124, 0.9940476417541504]

# %%
model2.evaluate(X_val,y_val)
# Out:
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5210 - accuracy: 0.9733
# [0.5210122466087341, 0.9732937812805176]

# %% [markdown]
# # Saving the model

# %%
saved_keras_model_filepath = '/kaggle/working/{}.h5'.format("sports image classification using mobilenet without Augmentation")
model2.save(saved_keras_model_filepath)

# %% [markdown]
# # Training with Augmentation

# %%
train_generator = ImageDataGenerator(    
    rotation_range=0.5,
    width_shift_range=0.2,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
)

# %%
Epochs=100
Batch_size=32
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model2.fit(train_generator.flow(X_train,y_train,batch_size=Batch_size,seed=27,shuffle=False),
                    epochs=Epochs,
                    steps_per_epoch=X_train.shape[0] // Batch_size,
                    validation_data=(X_val,y_val),
                    verbose=1)
# Out:
# Epoch 1/100
#
# 42/42 [==============================] - 17s 384ms/step - loss: 0.7194 - accuracy: 0.8400 - val_loss: 0.5887 - val_accuracy: 0.9436
#
# Epoch 2/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.7387 - accuracy: 0.8333 - val_loss: 0.6605 - val_accuracy: 0.9169
#
# Epoch 3/100
#
# 42/42 [==============================] - 15s 365ms/step - loss: 0.7105 - accuracy: 0.8527 - val_loss: 0.7351 - val_accuracy: 0.8783
#
# Epoch 4/100
#
# 42/42 [==============================] - 15s 361ms/step - loss: 0.7297 - accuracy: 0.8371 - val_loss: 0.7279 - val_accuracy: 0.8813
#
# Epoch 5/100
#
# 42/42 [==============================] - 16s 367ms/step - loss: 0.7590 - accuracy: 0.8155 - val_loss: 0.5688 - val_accuracy: 0.9466
#
# Epoch 6/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.7130 - accuracy: 0.8423 - val_loss: 0.6758 - val_accuracy: 0.9169
#
# Epoch 7/100
#
# 42/42 [==============================] - 16s 371ms/step - loss: 0.7282 - accuracy: 0.8348 - val_loss: 0.6522 - val_accuracy: 0.9199
#
# Epoch 8/100
#
# 42/42 [==============================] - 15s 358ms/step - loss: 0.7049 - accuracy: 0.8452 - val_loss: 0.5790 - val_accuracy: 0.9525
#
# Epoch 9/100
#
# 42/42 [==============================] - 16s 377ms/step - loss: 0.7190 - accuracy: 0.8400 - val_loss: 0.5724 - val_accuracy: 0.9555
#
# Epoch 10/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.6798 - accuracy: 0.8668 - val_loss: 0.6096 - val_accuracy: 0.9407
#
# Epoch 11/100
#
# 42/42 [==============================] - 16s 377ms/step - loss: 0.6923 - accuracy: 0.8512 - val_loss: 0.5888 - val_accuracy: 0.9466
#
# Epoch 12/100
#
# 42/42 [==============================] - 15s 359ms/step - loss: 0.7046 - accuracy: 0.8430 - val_loss: 0.5975 - val_accuracy: 0.9377
#
# Epoch 13/100
#
# 42/42 [==============================] - 16s 375ms/step - loss: 0.7021 - accuracy: 0.8445 - val_loss: 0.5563 - val_accuracy: 0.9555
#
# Epoch 14/100
#
# 42/42 [==============================] - 15s 353ms/step - loss: 0.7040 - accuracy: 0.8385 - val_loss: 0.5489 - val_accuracy: 0.9585
#
# Epoch 15/100
#
# 42/42 [==============================] - 16s 378ms/step - loss: 0.7042 - accuracy: 0.8385 - val_loss: 0.5315 - val_accuracy: 0.9674
#
# Epoch 16/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.6849 - accuracy: 0.8571 - val_loss: 0.5565 - val_accuracy: 0.9555
#
# Epoch 17/100
#
# 42/42 [==============================] - 16s 377ms/step - loss: 0.7239 - accuracy: 0.8408 - val_loss: 0.6172 - val_accuracy: 0.9318
#
# Epoch 18/100
#
# 42/42 [==============================] - 15s 358ms/step - loss: 0.6991 - accuracy: 0.8467 - val_loss: 0.5734 - val_accuracy: 0.9525
#
# Epoch 19/100
#
# 42/42 [==============================] - 15s 366ms/step - loss: 0.6806 - accuracy: 0.8601 - val_loss: 0.5485 - val_accuracy: 0.9674
#
# Epoch 20/100
#
# 42/42 [==============================] - 15s 361ms/step - loss: 0.6908 - accuracy: 0.8467 - val_loss: 0.5547 - val_accuracy: 0.9644
#
# Epoch 21/100
#
# 42/42 [==============================] - 16s 370ms/step - loss: 0.6769 - accuracy: 0.8609 - val_loss: 0.5448 - val_accuracy: 0.9644
#
# Epoch 22/100
#
# 42/42 [==============================] - 16s 373ms/step - loss: 0.7337 - accuracy: 0.8356 - val_loss: 0.5336 - val_accuracy: 0.9644
#
# Epoch 23/100
#
# 42/42 [==============================] - 16s 373ms/step - loss: 0.6921 - accuracy: 0.8512 - val_loss: 0.5344 - val_accuracy: 0.9614
#
# Epoch 24/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.7009 - accuracy: 0.8460 - val_loss: 0.5420 - val_accuracy: 0.9644
#
# Epoch 25/100
#
# 42/42 [==============================] - 16s 374ms/step - loss: 0.7192 - accuracy: 0.8385 - val_loss: 0.5355 - val_accuracy: 0.9674
#
# Epoch 26/100
#
# 42/42 [==============================] - 15s 357ms/step - loss: 0.7028 - accuracy: 0.8534 - val_loss: 0.5309 - val_accuracy: 0.9703
#
# Epoch 27/100
#
# 42/42 [==============================] - 16s 382ms/step - loss: 0.7142 - accuracy: 0.8341 - val_loss: 0.5420 - val_accuracy: 0.9644
#
# Epoch 28/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.6940 - accuracy: 0.8460 - val_loss: 0.5233 - val_accuracy: 0.9733
#
# Epoch 29/100
#
# 42/42 [==============================] - 15s 362ms/step - loss: 0.6980 - accuracy: 0.8534 - val_loss: 0.5383 - val_accuracy: 0.9585
#
# Epoch 30/100
#
# 42/42 [==============================] - 15s 362ms/step - loss: 0.6980 - accuracy: 0.8482 - val_loss: 0.5211 - val_accuracy: 0.9763
#
# Epoch 31/100
#
# 42/42 [==============================] - 15s 363ms/step - loss: 0.6943 - accuracy: 0.8490 - val_loss: 0.5279 - val_accuracy: 0.9733
#
# Epoch 32/100
#
# 42/42 [==============================] - 16s 377ms/step - loss: 0.6651 - accuracy: 0.8638 - val_loss: 0.5139 - val_accuracy: 0.9763
#
# Epoch 33/100
#
# 42/42 [==============================] - 15s 355ms/step - loss: 0.6763 - accuracy: 0.8579 - val_loss: 0.5383 - val_accuracy: 0.9614
#
# Epoch 34/100
#
# 42/42 [==============================] - 15s 364ms/step - loss: 0.6669 - accuracy: 0.8609 - val_loss: 0.5399 - val_accuracy: 0.9614
#
# Epoch 35/100
#
# 42/42 [==============================] - 15s 361ms/step - loss: 0.6904 - accuracy: 0.8542 - val_loss: 0.5323 - val_accuracy: 0.9674
#
# Epoch 36/100
#
# 42/42 [==============================] - 16s 370ms/step - loss: 0.6963 - accuracy: 0.8512 - val_loss: 0.5434 - val_accuracy: 0.9644
#
# Epoch 37/100
#
# 42/42 [==============================] - 15s 364ms/step - loss: 0.6805 - accuracy: 0.8571 - val_loss: 0.5371 - val_accuracy: 0.9614
#
# Epoch 38/100
#
# 42/42 [==============================] - 16s 377ms/step - loss: 0.6959 - accuracy: 0.8497 - val_loss: 0.5526 - val_accuracy: 0.9555
#
# Epoch 39/100
#
# 42/42 [==============================] - 15s 358ms/step - loss: 0.6946 - accuracy: 0.8512 - val_loss: 0.5496 - val_accuracy: 0.9614
#
# Epoch 40/100
#
# 42/42 [==============================] - 16s 370ms/step - loss: 0.6792 - accuracy: 0.8564 - val_loss: 0.5239 - val_accuracy: 0.9733
#
# Epoch 41/100
#
# 42/42 [==============================] - 15s 355ms/step - loss: 0.6664 - accuracy: 0.8676 - val_loss: 0.5529 - val_accuracy: 0.9614
#
# Epoch 42/100
#
# 42/42 [==============================] - 16s 377ms/step - loss: 0.6857 - accuracy: 0.8579 - val_loss: 0.5342 - val_accuracy: 0.9703
#
# Epoch 43/100
#
# 42/42 [==============================] - 15s 361ms/step - loss: 0.7054 - accuracy: 0.8408 - val_loss: 0.5291 - val_accuracy: 0.9703
#
# Epoch 44/100
#
# 42/42 [==============================] - 15s 365ms/step - loss: 0.6949 - accuracy: 0.8460 - val_loss: 0.5276 - val_accuracy: 0.9703
#
# Epoch 45/100
#
# 42/42 [==============================] - 15s 358ms/step - loss: 0.6995 - accuracy: 0.8497 - val_loss: 0.5357 - val_accuracy: 0.9674
#
# Epoch 46/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.6752 - accuracy: 0.8616 - val_loss: 0.5352 - val_accuracy: 0.9703
#
# Epoch 47/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.6848 - accuracy: 0.8519 - val_loss: 0.5318 - val_accuracy: 0.9703
#
# Epoch 48/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.6910 - accuracy: 0.8512 - val_loss: 0.5450 - val_accuracy: 0.9614
#
# Epoch 49/100
#
# 42/42 [==============================] - 15s 361ms/step - loss: 0.7235 - accuracy: 0.8296 - val_loss: 0.5466 - val_accuracy: 0.9674
#
# Epoch 50/100
#
# 42/42 [==============================] - 16s 366ms/step - loss: 0.6992 - accuracy: 0.8423 - val_loss: 0.5456 - val_accuracy: 0.9674
#
# Epoch 51/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.6839 - accuracy: 0.8601 - val_loss: 0.5429 - val_accuracy: 0.9703
#
# Epoch 52/100
#
# 42/42 [==============================] - 16s 370ms/step - loss: 0.7015 - accuracy: 0.8497 - val_loss: 0.5457 - val_accuracy: 0.9614
#
# Epoch 53/100
#
# 42/42 [==============================] - 15s 360ms/step - loss: 0.6978 - accuracy: 0.8519 - val_loss: 0.5699 - val_accuracy: 0.9525
#
# Epoch 54/100
#
# 42/42 [==============================] - 16s 380ms/step - loss: 0.6809 - accuracy: 0.8564 - val_loss: 0.5472 - val_accuracy: 0.9614
#
# Epoch 55/100
#
# 42/42 [==============================] - 15s 358ms/step - loss: 0.7050 - accuracy: 0.8430 - val_loss: 0.5343 - val_accuracy: 0.9674
#
# Epoch 56/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.7015 - accuracy: 0.8467 - val_loss: 0.5381 - val_accuracy: 0.9644
#
# Epoch 57/100
#
# 42/42 [==============================] - 15s 360ms/step - loss: 0.6728 - accuracy: 0.8624 - val_loss: 0.5411 - val_accuracy: 0.9674
#
# Epoch 58/100
#
# 42/42 [==============================] - 16s 370ms/step - loss: 0.6909 - accuracy: 0.8467 - val_loss: 0.5392 - val_accuracy: 0.9674
#
# Epoch 59/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.6948 - accuracy: 0.8475 - val_loss: 0.5340 - val_accuracy: 0.9674
#
# Epoch 60/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.7062 - accuracy: 0.8438 - val_loss: 0.5348 - val_accuracy: 0.9674
#
# Epoch 61/100
#
# 42/42 [==============================] - 15s 363ms/step - loss: 0.6803 - accuracy: 0.8601 - val_loss: 0.5377 - val_accuracy: 0.9674
#
# Epoch 62/100
#
# 42/42 [==============================] - 16s 373ms/step - loss: 0.6747 - accuracy: 0.8609 - val_loss: 0.5298 - val_accuracy: 0.9674
#
# Epoch 63/100
#
# 42/42 [==============================] - 15s 359ms/step - loss: 0.6826 - accuracy: 0.8549 - val_loss: 0.5321 - val_accuracy: 0.9674
#
# Epoch 64/100
#
# 42/42 [==============================] - 16s 369ms/step - loss: 0.6943 - accuracy: 0.8549 - val_loss: 0.5281 - val_accuracy: 0.9674
#
# Epoch 65/100
#
# 42/42 [==============================] - 15s 353ms/step - loss: 0.7247 - accuracy: 0.8296 - val_loss: 0.5193 - val_accuracy: 0.9733
#
# Epoch 66/100
#
# 42/42 [==============================] - 16s 379ms/step - loss: 0.6988 - accuracy: 0.8482 - val_loss: 0.5303 - val_accuracy: 0.9703
#
# Epoch 67/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.6917 - accuracy: 0.8482 - val_loss: 0.5265 - val_accuracy: 0.9703
#
# Epoch 68/100
#
# 42/42 [==============================] - 16s 375ms/step - loss: 0.7002 - accuracy: 0.8467 - val_loss: 0.5331 - val_accuracy: 0.9644
#
# Epoch 69/100
#
# 42/42 [==============================] - 15s 358ms/step - loss: 0.6974 - accuracy: 0.8557 - val_loss: 0.5487 - val_accuracy: 0.9614
#
# Epoch 70/100
#
# 42/42 [==============================] - 16s 383ms/step - loss: 0.7011 - accuracy: 0.8363 - val_loss: 0.5577 - val_accuracy: 0.9585
#
# Epoch 71/100
#
# 42/42 [==============================] - 15s 357ms/step - loss: 0.6910 - accuracy: 0.8497 - val_loss: 0.5537 - val_accuracy: 0.9614
#
# Epoch 72/100
#
# 42/42 [==============================] - 16s 371ms/step - loss: 0.6991 - accuracy: 0.8408 - val_loss: 0.5359 - val_accuracy: 0.9674
#
# Epoch 73/100
#
# 42/42 [==============================] - 15s 361ms/step - loss: 0.6953 - accuracy: 0.8467 - val_loss: 0.5403 - val_accuracy: 0.9674
#
# Epoch 74/100
#
# 42/42 [==============================] - 16s 372ms/step - loss: 0.6932 - accuracy: 0.8490 - val_loss: 0.5124 - val_accuracy: 0.9763
#
# Epoch 75/100
#
# 42/42 [==============================] - 15s 365ms/step - loss: 0.6884 - accuracy: 0.8609 - val_loss: 0.5197 - val_accuracy: 0.9733
#
# Epoch 76/100
#
# 42/42 [==============================] - 15s 357ms/step - loss: 0.6877 - accuracy: 0.8512 - val_loss: 0.5225 - val_accuracy: 0.9733
#
# Epoch 77/100
#
# 42/42 [==============================] - 15s 367ms/step - loss: 0.6681 - accuracy: 0.8698 - val_loss: 0.5219 - val_accuracy: 0.9703
#
# Epoch 78/100
#
# 42/42 [==============================] - 16s 372ms/step - loss: 0.6796 - accuracy: 0.8594 - val_loss: 0.5224 - val_accuracy: 0.9703
#
# Epoch 79/100
#
# 42/42 [==============================] - 15s 365ms/step - loss: 0.7260 - accuracy: 0.8378 - val_loss: 0.5236 - val_accuracy: 0.9674
#
# Epoch 80/100
#
# 42/42 [==============================] - 16s 369ms/step - loss: 0.6728 - accuracy: 0.8624 - val_loss: 0.5379 - val_accuracy: 0.9614
#
# Epoch 81/100
#
# 42/42 [==============================] - 15s 357ms/step - loss: 0.7311 - accuracy: 0.8296 - val_loss: 0.5397 - val_accuracy: 0.9644
#
# Epoch 82/100
#
# 42/42 [==============================] - 16s 373ms/step - loss: 0.6813 - accuracy: 0.8557 - val_loss: 0.5374 - val_accuracy: 0.9674
#
# Epoch 83/100
#
# 42/42 [==============================] - 15s 355ms/step - loss: 0.6984 - accuracy: 0.8460 - val_loss: 0.5324 - val_accuracy: 0.9703
#
# Epoch 84/100
#
# 42/42 [==============================] - 16s 386ms/step - loss: 0.7084 - accuracy: 0.8467 - val_loss: 0.5179 - val_accuracy: 0.9703
#
# Epoch 85/100
#
# 42/42 [==============================] - 15s 357ms/step - loss: 0.6666 - accuracy: 0.8698 - val_loss: 0.5199 - val_accuracy: 0.9733
#
# Epoch 86/100
#
# 42/42 [==============================] - 16s 381ms/step - loss: 0.6796 - accuracy: 0.8571 - val_loss: 0.5201 - val_accuracy: 0.9733
#
# Epoch 87/100
#
# 42/42 [==============================] - 15s 356ms/step - loss: 0.6772 - accuracy: 0.8549 - val_loss: 0.5212 - val_accuracy: 0.9703
#
# Epoch 88/100
#
# 42/42 [==============================] - 16s 368ms/step - loss: 0.6796 - accuracy: 0.8586 - val_loss: 0.5210 - val_accuracy: 0.9703
#
# Epoch 89/100
#
# 42/42 [==============================] - 15s 366ms/step - loss: 0.6873 - accuracy: 0.8549 - val_loss: 0.5210 - val_accuracy: 0.9703
#
# Epoch 90/100
#
# 42/42 [==============================] - 15s 359ms/step - loss: 0.6969 - accuracy: 0.8512 - val_loss: 0.5211 - val_accuracy: 0.9703
#
# Epoch 91/100
#
# 42/42 [==============================] - 15s 359ms/step - loss: 0.6871 - accuracy: 0.8571 - val_loss: 0.5225 - val_accuracy: 0.9703
#
# Epoch 92/100
#
# 42/42 [==============================] - 16s 367ms/step - loss: 0.7026 - accuracy: 0.8490 - val_loss: 0.5176 - val_accuracy: 0.9703
#
# Epoch 93/100
#
# 42/42 [==============================] - 16s 378ms/step - loss: 0.6978 - accuracy: 0.8512 - val_loss: 0.5148 - val_accuracy: 0.9733
#
# Epoch 94/100
#
# 42/42 [==============================] - 16s 372ms/step - loss: 0.7097 - accuracy: 0.8400 - val_loss: 0.5146 - val_accuracy: 0.9733
#
# Epoch 95/100
#
# 42/42 [==============================] - 15s 362ms/step - loss: 0.6877 - accuracy: 0.8579 - val_loss: 0.5142 - val_accuracy: 0.9733
#
# Epoch 96/100
#
# 42/42 [==============================] - 16s 367ms/step - loss: 0.6867 - accuracy: 0.8512 - val_loss: 0.5103 - val_accuracy: 0.9703
#
# Epoch 97/100
#
# 42/42 [==============================] - 15s 357ms/step - loss: 0.6829 - accuracy: 0.8549 - val_loss: 0.5141 - val_accuracy: 0.9703
#
# Epoch 98/100
#
# 42/42 [==============================] - 16s 369ms/step - loss: 0.6775 - accuracy: 0.8624 - val_loss: 0.5295 - val_accuracy: 0.9674
#
# Epoch 99/100
#
# 42/42 [==============================] - 15s 354ms/step - loss: 0.6610 - accuracy: 0.8690 - val_loss: 0.5303 - val_accuracy: 0.9674
#
# Epoch 100/100
#
# 42/42 [==============================] - 16s 379ms/step - loss: 0.6916 - accuracy: 0.8490 - val_loss: 0.5303 - val_accuracy: 0.9674

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(Epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model2.evaluate(X_train,y_train)
# Out:
# 2022-12-25 20:13:44.041603: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 809238528 exceeds 10% of free system memory.
# 42/42 [==============================] - 1s 26ms/step - loss: 0.4582 - accuracy: 0.9948
# [0.4581979513168335, 0.9947916865348816]

# %%
model2.evaluate(X_val,y_val)
# Out:
# 11/11 [==============================] - 0s 26ms/step - loss: 0.5303 - accuracy: 0.9674
# [0.530289351940155, 0.9673590660095215]

# %% [markdown]
# # Saving the model

# %%
saved_keras_model_filepath = '/kaggle/working/{}.h5'.format("sports image classification using mobilenet with Augmentation")
model2.save(saved_keras_model_filepath)

# %% [markdown]
# # Load the model

# %%
reloaded_keras_model=tf.keras.models.load_model('/kaggle/input/model-station1/model station1.h5')
reloaded_keras_model.summary()
# Out:
# Model: "sequential"
#
# _________________________________________________________________
#
# Layer (type)                 Output Shape              Param #
#
# =================================================================
#
# mobilenet_1.00_224 (Function (None, 1000)              4253864
#
# _________________________________________________________________
#
# dropout (Dropout)            (None, 1000)              0
#
# _________________________________________________________________
#
# dense (Dense)                (None, 6)                 6006
#
# =================================================================
#
# Total params: 4,259,870
#
# Trainable params: 4,237,982
#
# Non-trainable params: 21,888
#
# _________________________________________________________________

# %% [markdown]
# # Predict our test data

# %%
test_path =r"/kaggle/input/nn23-sports-image-classification/Test"
test_imgs=os.listdir(test_path)

# %%
# reading test data
l_test=reading_resize(test_imgs,test_path,image_size)

# %%
test = np.array(l_test)
print(test.shape)
# Out:
# (688, 224, 224, 3)

# %%
plt.imshow(test[200])

# %%
test_names=[]
for g in test_imgs:   
    test_names.append(g)

# %%
len(test_names)
# Out:
# 688

# %%
#normalize
test=test/255.0

# %%
test_out=reloaded_keras_model.predict(test)

# %%
#pred
p=test_out

plt.figure(figsize=(25,25))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test[i])
    plt.xlabel(get_name(np.argmax(p[i])))
plt.show()

# %%
pred_out=[]
for i in range(len(test_out)):
    label=np.argmax(test_out[i])
    pred_out.append([test_names[i],label])

# %%
# pred_out

# %%
Datapd=pd.DataFrame(pred_out,columns=['image_name','label'])
Datapd.head()
# Out:
#   image_name  label
# 0    623.jpg      2
# 1    208.jpg      5
# 2    473.jpg      0
# 3    333.jpg      1
# 4    537.jpg      1

# %%
Datapd.to_csv('/kaggle/working/sports_6_classs_preds__.csv',index=False)
